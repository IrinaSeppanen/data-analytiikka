# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

plt.style.use("seaborn-whitegrid")

# %%
df = pd.read_excel("http://taanila.fi/data3.xlsx")
df.head()
# Out:
#    nro  toimitusnopeus  hintataso  joustavuus hinnoissa  toimittajan imago  \
# 0    1             4.1        0.6                   6.9                4.7
# 1    2             1.8        3.0                   6.3                6.6
# 2    3             3.4        5.2                   5.7                6.0
# 3    4             2.7        1.0                   7.1                5.9
# 4    5             6.0        0.9                   9.6                7.8
#
#    palvelu  myyntihenkilöstön imago  tuotteiden laatu  yleinen tyytyväisyys
# 0      2.4                      2.3               5.2                   4.2
# 1      2.5                      4.0               8.4                   4.3
# 2      4.3                      2.7               8.2                   5.2
# 3      1.8                      2.3               7.8                   3.9
# 4      3.4                      4.6               4.5                   6.8

# %%
df = df.drop("nro", axis = 1)

# %%
dims = (14, 3)
fig, ax = plt.subplots(figsize=dims)

sns.boxplot(data=df, orient = "v")
plt.xticks(rotation=30)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]), <a list of 8 Text xticklabel objects>)

# %%
opintomenestys = pd.read_excel("http://taanila.fi/opintomenestys.xlsx").drop("koehenkilö", axis=1)
#opintomenestys=opintomenestys.drop("koehenkilö", axis=1)
sns.heatmap(opintomenestys.corr(), annot=True)
